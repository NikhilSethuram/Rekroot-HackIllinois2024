# %%
# Installations
# !pip install langchain

# %%
# DATA COLLECTION

# TODO: get this from the uploaded and OCRd resume
resume_text = """
                                                                     YASH GUPTA
                                       ysgupta@wisc.edu | +1 (858) 252-8030 | https://www.linkedin.com/in/yashsgupta/

EDUCATION
University of Wisconsin, Madison - Computer Science + Data Science B.S., Entrepreneurship Minor                                                                May 2025
Related Courses: Object Oriented Programming, Advanced Data Structures, Data Management & Statistical Analysis in R, Introduction to Python, Linear Algebra, Machine
Organization and Programming, Advanced Data Analysis and Visualization with Python, Discrete Mathematics


TECHNICAL EXPERIENCE
The Level Company - Intern                                                                                                                         June 2023 - Present
     ●    Created sequential large language models with GPT-4 using LangChain in Python for multi-stage process to generate effective and personalized messages to
          enable more connections with potential advisors, resulting in significantly higher response rates
     ●    Collaborated with client services team to utilize Linkedin Sales Navigator to automate finding advisors, sourcing over 200 new advisors
     ●    Automated reengagement email outreach campaigns using SendGrid API and Python, leading to an increase of over 50% in re engagement rates
     ●    Worked with Linkedin APIs to automate scraping profile information and implemented Python algorithms to filter JSON and spreadsheets for relevant fields

UC San Diego: Division of Biomedical Informatics - Intern                                                                                    June 2020 - March 2023
     ●    Worked on creating efficient and secure medical data transfer through Ethereum blockchain
     ●    Headed development on user interface for medical data using Java and HTML5/CSS3
     ●    Utilized Solidity and managed AWS virtual machines to work on the backend of the blockchain
     ●    Implemented in 12 university hospitals with high success rates
     ●    Co-author on publication in Journal of American Medical Informatics Association (JAMIA); presented work to National Institute of Health officials at local
          conference


PROJECTS
enRollBadge (enrollbadge.com)                                                                                                                    May 2023 - Present
     ●    Created unique software that allowed UW Madison students to receive real time notifications when class seats open
     ●    Led a team of 4 developers to seamlessly integrate the API and scraping functionality to enable efficient data exchange between backend and frontend
     ●    Headed development and continuously maintained on frontend and user interface in ReactJS and Tailwind CSS
     ●    Implemented JSON parsing algorithms in Python to process data received from the backend API
     ●    Developed a dynamic table using ReactJS to display and manage class information, with integrated search functionality.
     ●    Utilized effective marketing strategies resulting in a significant increase in site views, with over a thousand visits, and generated hundreds of new sign-ups
          within a span of two days.

Analyzing the Effectiveness of Novel Classification                                                                                          July 2020 - June 2021
Techniques for Detecting Knee Cartilage Damage
     ●    Designed machine learning models with accuracy of over 95% to detect knee cartilage ruptures in knee cartilage MRI images early and counter osteoarthritis,
          outperforming traditional human methods
     ●    Created dataset with Python algorithms that filter, preprocessed, and merged a combination of 1.2 million knee MRI images from different sources
     ●    Utilized Tensorflow and Python to develop and deploy machine learning models on dataset
     ●    Developed precise accuracy metrics to compare effectiveness of different machine learning models to find the most optimal model using SciKit Learn
     ●    Recognized as 1st place in San Diego Greater Science and Engineering Fair and qualifier to California State Fair


EXTRACURRICULAR
Northwestern University’s WildHacks Participant                                                                                                        April 2023
     ●    Designed web application with a team of 4 developers that allows dyslexic kids to gain personalized training against certain issues in a fun and interactive way
          through a series of mini games
     ●    Received Best Accessibility Hack Award Sponsored by Fidelity out of 387 participants across the country
     ●    Created game recommendation machine learning model implemented in SciKit Learn to recommend users games based on diagnostic test
     ●    Created word recommendation model for mini-game, WordWhiz, using Naive Bayes classifier implemented with SciKit Learn
     ●    Developed Flask API to communicate and integrate machine learning model into frontend
     ●    Developed frontend form page for diagnostic quiz using React.JS and Tailwind CSS


SKILLS
     ❖ Programming Languages: Java, Python, C, HTML/CSS, Git, Bash, R, SQL
     ❖ Web Development: HTML5, CSS3, JavaScript, NodeJS, ReactJS, NextJS, TailwindCSS, Flask, A/B Testing
     ❖ Frameworks: Tensorflow, PyTorch, ScikitLearn, Pandas, AWS (EC2), SQLite, Selenium

"""

# TODO: get this from the job description attached to the swiped card
job_descrip = """

Description\n\nBRGʼs 340B team is one of the Healthcare Analytics practice's largest and fastest-growing groups! The 340B team supports and advises pharmaceutical manufacturers on navigating the challenges and complexities of the 340B program, a government drug purchasing program. Our group is the established market leader in data and technology solutions related to the most pressing 340B-related... issues for an impressive client base, including the largest pharmaceutical manufacturers in the US. Beyond our syndicated solutions, we also integrate and synthesize data to deliver unparalleled analytics and insights into various aspects of the 340B program.\n\nOur 340B group is currently looking to expand our talented and dynamic product and development team. We are currently seeking front-end and full-stack Software Engineers and Senior Software Engineers who are passionate about solving challenging problems! Our software engineers take part in creating some of the most innovative software solutions in the dynamic and fascinating field of healthcare analytics. The 340B program is an exciting and vibrant space to be in right now, so come join us!\n\nJob title and compensation to be determined based on qualifications and experience.\u202f\n\nResponsibilities:\n• With your technical expertise you will manage project priorities, deadlines, and deliverables.\n• You will design, develop, test, deploy, maintain, and enhance software solutions.\n• Write product or system development code.\n• Participate in, or lead design reviews with peers and stakeholders to decide amongst available technologies.\n• Review code developed by other developers and provide feedback to ensure best practices (e.g., style guidelines, checking code in, accuracy, testability, and efficiency).\n• Contribute to existing documentation or educational content and adapt content based on product/program updates and user feedback.\n• Triage product or system issues and debug/track/resolve by analyzing the sources of issues and the impact on hardware, network, or service operations and quality.\n• Work in an environment that supports your individual growth.\n• Collaborate closely with other engineers and become a valued member of an autonomous, impactful, cross-functional team.\n\nTechnical Skill Set:\n• 5+ years of software development experience in one or more of the following programming languages: React, TypeScript, JavaScript, Ruby, Ruby on Rails, and/or Go/Golang.\n• Experience with Agile SDLC methodology, Jira, GitHub, Git (git-flow, merge, rebase, squashing, branch management) and working in a CI/CD environment.\n• Experience with one or more of the following: Kubernetes, MongoDB, Docker, and/or Microsoft Azure is a plus.\n\nRequirements:\n• 5+ years of solid software development experience; A minimum of 8-10+ years is required for the Senior level position. Job title to be determined based on relevant qualifications and experience.\u202f\n• Bachelor’s degree in Computer Science, Information Technology or a related field.\n• Strong problem-solving and analytical skills, with the ability to make quick decisions in a fast-paced environment with complete ownership.\n• Experience with code quality, continuous delivery, and automated testing.\n• Comfortable working in an agile environment and challenging yourself and your team to improve their ways of working.\n• Experience building scalable, user-friendly web applications.\n\nSalary Range: $100,000 - $230,000 per year\n\nCandidate must be able to submit verification of their legal right to work in the U.S., without company sponsorship.\n\n#LI-JQ1 | #LI-REMOTE", 'job_highlights': [{'title': 'Qualifications', 'items': ['5+ years of software development experience in one or more of the following programming languages: React, TypeScript, JavaScript, Ruby, Ruby on Rails, and/or Go/Golang', 'Experience with Agile SDLC methodology, Jira, GitHub, Git (git-flow, merge, rebase, squashing, branch management) and working in a CI/CD environment', '5+ years of solid software development experience; A minimum of 8-10+ years is required for the Senior level position', 'Job title to be determined based on relevant qualifications and experience.', 'Bachelor’s degree in Computer Science, Information Technology or a related field', 'Strong problem-solving and analytical skills, with the ability to make quick decisions in a fast-paced environment with complete ownership', 'Experience with code quality, continuous delivery, and automated testing', 'Comfortable working in an agile environment and challenging yourself and your team to improve their ways of working', 'Experience building scalable, user-friendly web applications', 'Candidate must be able to submit verification of their legal right to work in the U.S., without company sponsorship']}, {'title': 'Responsibilities', 'items': ['With your technical expertise you will manage project priorities, deadlines, and deliverables', 'You will design, develop, test, deploy, maintain, and enhance software solutions', 'Write product or system development code', 'Participate in, or lead design reviews with peers and stakeholders to decide amongst available technologies', 'Review code developed by other developers and provide feedback to ensure best practices (e.g., style guidelines, checking code in, accuracy, testability, and efficiency)', 'Contribute to existing documentation or educational content and adapt content based on product/program updates and user feedback', 'Triage product or system issues and debug/track/resolve by analyzing the sources of issues and the impact on hardware, network, or service operations and quality', 'Work in an environment that supports your individual growth', 'Collaborate closely with other engineers and become a valued member of an autonomous, impactful, cross-functional team']}, {'title': 'Benefits', 'items': ['Salary Range: $100,000 - $230,000 per year'

"""

openai_api_key = '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'

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage

# MODEL CREATION

sys_prompt = """

Given a candidate's resume and a job description, generate a very brief (around 50-100 words) personalized message to a recruiter that emphasizes the candidate's interest in the position and suitability based on their skills and experience. The message should be professional, engaging, and demonstrate a genuine understanding of the job requirements and how the candidate's background aligns with these needs. Ensure the message subtly highlights key achievements and relevant experiences without being overly boastful, and expresses enthusiasm for the opportunity to contribute to the company.

Resume Summary:
- [Candidate's Summary: Include a very brief overview of the candidate's professional background, key skills, and notable achievements.]

Job Description Summary:
- [Job Description: Summarize the job role, essential skills, and qualifications required for the position, along with any specific company values or cultural aspects mentioned.]

Generate Message:
- Greeting: [Use a professional and friendly opening.]
- Introduction: [Mention how the candidate discovered the job and express genuine interest.]
- Suitability: [Highlight how the candidate's skills and experiences align with the job requirements. Include specific examples or achievements that demonstrate relevant competencies.]
- Company Alignment: [Mention any specific reasons the candidate is excited about the opportunity to work at the company, referencing the company's values, mission, or projects that resonate with the candidate.]
- Closing: [Express eagerness to discuss how the candidate can contribute to the team and thank the recruiter for considering the application. Ask about potentially setting up a follow up meeting to learn more about the company, see where you can contribute in the role, and gaining more advice about navigating through application process.]

Note: Asking for the call needs to happen in every single message at the end. Do not forget this. 
Note: Tailor the message to ensure it feels personalized to both the candidate and the job, avoiding generic phrases that could apply to any application. Additionally, make it seem more human.

"""


chat_model = ChatOpenAI(temperature=0, model_name='gpt-4', openai_api_key=openai_api_key)

output = chat_model(
    [
        # give context on Level
        
        SystemMessage(content=sys_prompt),
        HumanMessage(content=f'Given the resume and the job description below, generate an optimal short personalized message that I could send to my recruiter to demonstrate interest and improve my chances at securing a job subtly. \n Resume:\n{resume_text}\n\n Job Description:\n{job_descrip}')
    ]
)

outputtext = str(output)[len('content="'):-1]

print(outputtext)
# Out:
# Dear Recruiter,\n\nI am writing to express my interest in the Software Engineer position at BRG's 340B team, as advertised. As a Computer Science and Data Science student at the University of Wisconsin, Madison, I have honed my skills in various programming languages, including React and JavaScript, which are key requirements for this role.\n\nMy experience as an intern at The Level Company and UC San Diego's Division of Biomedical Informatics has equipped me with a strong understanding of software development, project management, and problem-solving. Notably, I led a team to create a unique software that allowed students to receive real-time notifications when class seats open, demonstrating my ability to build scalable, user-friendly web applications.\n\nI am particularly drawn to BRG's commitment to creating innovative software solutions in the dynamic field of healthcare analytics. I am excited about the opportunity to contribute to your team and further enhance my skills in a ch
# ...
