# %%
# Installations
# !pip install langchain

# %%
import os 

os.environ['OPENAI_API_KEY'] = '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'

# %%
# DATA COLLECTION

# TODO: get this from the uploaded and OCRd resume
resume_text = """
                                                                     YASH GUPTA
                                       ysgupta@wisc.edu | +1 (858) 252-8030 | https://www.linkedin.com/in/yashsgupta/

EDUCATION
University of Wisconsin, Madison - Computer Science + Data Science B.S., Entrepreneurship Minor                                                                May 2025
Related Courses: Object Oriented Programming, Advanced Data Structures, Data Management & Statistical Analysis in R, Introduction to Python, Linear Algebra, Machine
Organization and Programming, Advanced Data Analysis and Visualization with Python, Discrete Mathematics


TECHNICAL EXPERIENCE
The Level Company - Intern                                                                                                                         June 2023 - Present
     ●    Created sequential large language models with GPT-4 using LangChain in Python for multi-stage process to generate effective and personalized messages to
          enable more connections with potential advisors, resulting in significantly higher response rates
     ●    Collaborated with client services team to utilize Linkedin Sales Navigator to automate finding advisors, sourcing over 200 new advisors
     ●    Automated reengagement email outreach campaigns using SendGrid API and Python, leading to an increase of over 50% in re engagement rates
     ●    Worked with Linkedin APIs to automate scraping profile information and implemented Python algorithms to filter JSON and spreadsheets for relevant fields

UC San Diego: Division of Biomedical Informatics - Intern                                                                                    June 2020 - March 2023
     ●    Worked on creating efficient and secure medical data transfer through Ethereum blockchain
     ●    Headed development on user interface for medical data using Java and HTML5/CSS3
     ●    Utilized Solidity and managed AWS virtual machines to work on the backend of the blockchain
     ●    Implemented in 12 university hospitals with high success rates
     ●    Co-author on publication in Journal of American Medical Informatics Association (JAMIA); presented work to National Institute of Health officials at local
          conference


PROJECTS
enRollBadge (enrollbadge.com)                                                                                                                    May 2023 - Present
     ●    Created unique software that allowed UW Madison students to receive real time notifications when class seats open
     ●    Led a team of 4 developers to seamlessly integrate the API and scraping functionality to enable efficient data exchange between backend and frontend
     ●    Headed development and continuously maintained on frontend and user interface in ReactJS and Tailwind CSS
     ●    Implemented JSON parsing algorithms in Python to process data received from the backend API
     ●    Developed a dynamic table using ReactJS to display and manage class information, with integrated search functionality.
     ●    Utilized effective marketing strategies resulting in a significant increase in site views, with over a thousand visits, and generated hundreds of new sign-ups
          within a span of two days.

Analyzing the Effectiveness of Novel Classification                                                                                          July 2020 - June 2021
Techniques for Detecting Knee Cartilage Damage
     ●    Designed machine learning models with accuracy of over 95% to detect knee cartilage ruptures in knee cartilage MRI images early and counter osteoarthritis,
          outperforming traditional human methods
     ●    Created dataset with Python algorithms that filter, preprocessed, and merged a combination of 1.2 million knee MRI images from different sources
     ●    Utilized Tensorflow and Python to develop and deploy machine learning models on dataset
     ●    Developed precise accuracy metrics to compare effectiveness of different machine learning models to find the most optimal model using SciKit Learn
     ●    Recognized as 1st place in San Diego Greater Science and Engineering Fair and qualifier to California State Fair


EXTRACURRICULAR
Northwestern University’s WildHacks Participant                                                                                                        April 2023
     ●    Designed web application with a team of 4 developers that allows dyslexic kids to gain personalized training against certain issues in a fun and interactive way
          through a series of mini games
     ●    Received Best Accessibility Hack Award Sponsored by Fidelity out of 387 participants across the country
     ●    Created game recommendation machine learning model implemented in SciKit Learn to recommend users games based on diagnostic test
     ●    Created word recommendation model for mini-game, WordWhiz, using Naive Bayes classifier implemented with SciKit Learn
     ●    Developed Flask API to communicate and integrate machine learning model into frontend
     ●    Developed frontend form page for diagnostic quiz using React.JS and Tailwind CSS


SKILLS
     ❖ Programming Languages: Java, Python, C, HTML/CSS, Git, Bash, R, SQL
     ❖ Web Development: HTML5, CSS3, JavaScript, NodeJS, ReactJS, NextJS, TailwindCSS, Flask, A/B Testing
     ❖ Frameworks: Tensorflow, PyTorch, ScikitLearn, Pandas, AWS (EC2), SQLite, Selenium

"""

# TODO: get this from the job description attached to the swiped card
job_descrip =

# %%
# MODEL CREATION

sys_prompt = """

Given a candidate's resume and a job description, generate a personalized message to a recruiter that emphasizes the candidate's interest in the position and suitability based on their skills and experience. The message should be professional, engaging, and demonstrate a genuine understanding of the job requirements and how the candidate's background aligns with these needs. Ensure the message subtly highlights key achievements and relevant experiences without being overly boastful, and expresses enthusiasm for the opportunity to contribute to the company.

Resume Summary:
- [Candidate's Summary: Include a brief overview of the candidate's professional background, key skills, and notable achievements.]

Job Description Summary:
- [Job Description: Summarize the job role, essential skills, and qualifications required for the position, along with any specific company values or cultural aspects mentioned.]

Generate Message:
- Greeting: [Use a professional and friendly opening.]
- Introduction: [Mention how the candidate discovered the job and express genuine interest.]
- Suitability: [Highlight how the candidate's skills and experiences align with the job requirements. Include specific examples or achievements that demonstrate relevant competencies.]
- Company Alignment: [Mention any specific reasons the candidate is excited about the opportunity to work at the company, referencing the company's values, mission, or projects that resonate with the candidate.]
- Closing: [Express eagerness to discuss how the candidate can contribute to the team and thank the recruiter for considering the application. Provide contact information and availability for an interview.]

Note: Tailor the message to ensure it feels personalized to both the candidate and the job, avoiding generic phrases that could apply to any application.

"""


chat_model = ChatOpenAI(temperature=0, model_name='gpt-4', openai_api_key=openai_api_key)

output = chat_model(
    [
        # give context on Level
        
        SystemMessage(content=sys_prompt),
        HumanMessage(content=f'Given the resume below and the job description below')
        
    ]
)

# %%
# INSTALLATIONS

# !pip install langchain
# !pip install gspread

# %%
# ENVIRONMENT VARIABLES

import os 

os.environ['OPENAI_API_KEY'] = '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'

# %% [markdown]
# # ProxyCurl JSON
#
#
# ## Manual Creation
#
# The cells below use the CSV to create the ProxyCurl output and simply output to console.
#
# The cell below extracts all the data.

# %%
# importing module
from pandas import *

# reading CSV file
data = read_csv("data/profilestest.csv")

# converting column data to list
names = data['Name'].tolist()
urls = data['Linkedin Profile URL'].tolist()

# printing list data
print('Name: ', names)
print('URL: ', urls)
# Out:
# Name:  ['Erik Cobham', 'Marc Cormier', 'Bill Blackstock', 'Joseph Mina', 'David Byrnes']
# URL:  ['https://www.linkedin.com/in/erikcobham/', 'https://www.linkedin.com/in/marc-cormier-652b6263/', 'https://www.linkedin.com/in/bill-blackstock-a0971474/', 'https://www.linkedin.com/in/joseph-mina-6a46952/', 'https://www.linkedin.com/in/david-byrnes-31b38779/']

# %% [markdown]
# ## Extract Data from the Spreadsheet
#
# Instead of getting it from the CSV, let's try getting names and URLS from the spreadsheet

# %%
import gspread

gc = gspread.service_account()

level_sheet = gc.open_by_url("https://docs.google.com/spreadsheets/d/17nvGq6ZwBg3LHO_-pWAfCajH1a0HN7FbQnkSYg-1Wbk/edit?usp=sharing")
level_data = level_sheet.get_worksheet(0)
prompt_data = level_sheet.get_worksheet(1)

prompts_col = prompt_data.col_values(4)

# names_col = level_data.col_values(1)
urls_col = level_data.col_values(3)

# names = names_col[names_col.index("Name") + 1:]
urls = urls_col[urls_col.index("LinkedIn URL") + 1:]

# %% [markdown]
# ## Use ProxyCurl to get the JSON

# %%
# Out:
# {"public_identifier": "yashsgupta", "profile_pic_url": "https://s3.us-west-000.backblazeb2.com/proxycurl/person/yashsgupta/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20230804%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20230804T223902Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=16cc7de63b306a87da58fdcd7d907b844ba47808cc217cc8ee17c40115f25be3", "background_cover_image_url": null, "first_name": "Yash", "last_name": "Gupta", "full_name": "Yash Gupta", "follower_count": null, "occupation": null, "headline": "Hardworking, passionate machine learning researcher, developer, and entrepreneur\n", "summary": "I am Yash Gupta, a 10th grader at Canyon Crest Academy. I have been programming all of my life, starting at the young age of 6 years old. Through my years of experience, I have became proficient in multiple languages, such as HTML/CSS, Python, C. I also acquired knowledge about embedded systems through various projects over the 
# ...

# %%
import requests

api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
api_key = '88ae5492-12a5-4dbc-a046-f29a76c3ea7b'
header_dic = {'Authorization': 'Bearer ' + api_key}

params = {
        'url': 'https://www.linkedin.com/in/rachel-dietz-1a590b10a/',
        'personal_email': 'include',
        'personal_contact_number': 'include',
}
    
response = requests.get(api_endpoint,
                            params=params,
                            headers=header_dic)
    
text = response.text
    
print(text)




# for u in urls:
#     params = {
#         'url': u,
#         'personal_email': 'include',
#         'personal_contact_number': 'include',
#     }
    
#     response = requests.get(api_endpoint,
#                             params=params,
#                             headers=header_dic)
    
#     text = response.text
    
#     level_data.update(f"D{urls.index(u) + 3}", text)
# Out:
# {"public_identifier": "rachel-dietz-1a590b10a", "profile_pic_url": null, "background_cover_image_url": null, "first_name": "Rachel", "last_name": "Dietz", "full_name": "Rachel Dietz", "follower_count": null, "occupation": null, "headline": "Recruiter at Abercrombie & Fitch Co.", "summary": null, "country": "US", "country_full_name": null, "city": "Columbus", "state": "Ohio", "experiences": [{"starts_at": {"day": 1, "month": 7, "year": 2019}, "ends_at": null, "company": "abercrombie & fitch", "company_linkedin_profile_url": null, "title": "recruiter", "description": null, "location": "columbus, ohio, united states", "logo_url": null}, {"starts_at": {"day": 1, "month": 1, "year": 2015}, "ends_at": {"day": 1, "month": 1, "year": 2017}, "company": "double eagle club", "company_linkedin_profile_url": null, "title": "server", "description": null, "location": "columbus, ohio, united states", "logo_url": null}, {"starts_at": {"day": 1, "month": 8, "year": 2014}, "ends_at": {"day": 1, "month"
# ...

# %% [markdown]
# ## Filter out the JSON
#
# Filter URLs and empty fields from each JSON

# %%
import json

json_col = level_data.col_values(4)
pc_jsons = json_col[json_col.index("Proxycurl JSON") + 1:]

def remove_urls(data):
    if isinstance(data, dict):
        for key, value in list(data.items()):
            if isinstance(value, str) and value.startswith("http"):
                del data[key]
            elif isinstance(value, dict) or isinstance(value, list):
                remove_urls(value)
    elif isinstance(data, list):
        for item in data:
            remove_urls(item)

# TODO: need to fix this
def remove_empty_elements(d):
    """recursively remove empty lists, empty dicts, or None elements from a dictionary"""
    
    def empty(x):
        return x is None or x == {} or x == [] or x == ""

    if not isinstance(d, (dict, list)):
        return d
    elif isinstance(d, list):
        return [v for v in (remove_empty_elements(v) for v in d) if not empty(v)]
    else:
        return {k: v for k, v in ((k, remove_empty_elements(v)) for k, v in d.items()) if not empty(v)}

filtered_json_list = []  # List to store filtered JSON strings

for j in pc_jsons:
    j_obj = json.loads(j)
    
    remove_empty_elements(remove_urls(j_obj))  # Update j_obj with the cleaned JSON
    
    level_data.update(f"E{pc_jsons.index(j) + 3}", str(j_obj))

# %% [markdown]
# ## Extract email and phone numbers

# %%
import json

json_col = level_data.col_values(4)
pc_jsons = json_col[json_col.index("Proxycurl JSON") + 1:]

for j in pc_jsons:
    j_obj = json.loads(j)
    
    level_data.update(f"F{pc_jsons.index(j) + 3}", ", ".join(j_obj["personal_emails"]))
    
    phone_numbers_list = []
    
    if len(j_obj["personal_numbers"]) == 0:
        if "phone_numbers" in j_obj and len(j_obj["phone_numbers"]) > 0:
            phone_numbers_list = j_obj["phone_numbers"]
    else:
        if "phone_numbers" in j_obj and len(j_obj["phone_numbers"]) > 0:
            phone_numbers_list +=  j_obj["phone_numbers"]
        phone_numbers_list = j_obj["personal_numbers"]
    
    level_data.update(f"G{pc_jsons.index(j) + 3}", ", ".join(phone_numbers_list))

# %% [markdown]
# ## Best fields to send
#
# Below is the initial chat model that contains just the simple output of what the best fields to send were

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage

json_col = level_data.col_values(5)
pc_jsons = json_col[json_col.index("Filtered JSON") + 1:]

openai_api_key = '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'

for j in pc_jsons:
    
    chat_model = ChatOpenAI(temperature=0, model_name='gpt-4', openai_api_key=openai_api_key)
    
    
    output = chat_model(
    [
        # give context on Level
        
        SystemMessage(content="You are an AI that helps the user figure out what fields in the JSON passed in are relevant to know when talking to the potential advisor."),
        HumanMessage(content=f'Return me a filtered JSON : {j}')
        
    ]
    )
    
    # Remove leading 'content=' and trailing ' additional_kwargs={} example=False'
    csv_outputtext = str(output).replace('content=\'', '').replace('\' additional_kwargs={} example=False', '')
    
    print(csv_outputtext)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/j0/dhfgpfdx2dqdk0_lk2mzx5r40000gn/T/ipykernel_26161/1883894735.py in <module>
#      12
#      13
# ---> 14     output = chat_model(
#      15     [
#      16         # give context on Level
#
# ~/opt/anaconda3/lib/python3.9/site-packages/langchain/chat_models/base.py in __call__(self, messages, stop, callbacks, **kwargs)
#     340         **kwargs: Any,
#     341     ) -> BaseMessage:
# --> 342         generation = self.generate(
#     343             [messages], stop=stop, callbacks=callbacks, **kwargs
#     344         ).generations[0][0]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/langchain/chat_models/base.py in generate(self, messages, stop, callbacks, tags, **kwargs)
#     119                 if run_managers:
#     120                     run_managers[i].on_llm_error(e)
# --> 121                 raise e
# ...

# %% [markdown]
# Here is the revised chat model with the system prompt of a summary of what Level does, some client information, and more keywords (prompt 06/29)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage
import re

level_context = """
Level Company is an innovative platform that connects businesses with trusted advisors who have strong relationships with decision-makers at large organizations. Their mission is to help businesses pitch their value proposition to the right people, shorten sales cycles, and increase the likelihood of securing high-value accounts. They address critical challenges faced by businesses when targeting such accounts, including difficulty accessing key decision-makers, time-consuming prospecting, and lack of tailored insights.

To overcome these challenges, Level Company developed a relationship-based approach that leverages human connections and industry insights. Their platform connects businesses with advisors who have established relationships with decision-makers, streamlines prospecting through introductions and relevant insights, and enables personalized value propositions. By leveraging their platform's insights and introductions, businesses can accelerate sales cycles, scale their efforts, and gain access to an exclusive network of top-level executives.

Overall, Level Company offers an efficient and effective solution that complements traditional sales and marketing strategies. They revolutionize the business landscape by helping businesses secure high-value accounts, drive growth, and capitalize on the value of human connections and tailored insights.
"""

clients = {
    "BairesDev": """
    "BairesDev is a leading Nearshore Outsourcing company that specializes in developing scalable and high-performing technology solutions for a diverse array of clients, including Fortune 500 companies. The company leverages its proficient team of software engineers and the latest technologies to innovate and digitally empower businesses across different sectors.

BairesDev's team, distributed across 36 countries, integrates seamlessly with client's in-house teams using agile methodologies. Their service offering is designed to facilitate digital transformation and includes everything from requirements and systems analysis to architecture, design, development, testing, migration, and deployment.

The company prides itself on its stringent recruitment process which selects only the top 1% of tech engineers from over 1.2 million applicants annually. To optimally assemble teams for different projects, BairesDev utilizes a proprietary system called Staffing Hero™, ensuring that the teams are not only technologically proficient but are also suitable for the specific client and project needs.

In summary, BairesDev delivers bespoke software development services, providing high-quality technological solutions to solve business needs and bolster digital acceleration. Their key strengths lie in their top-tier engineering talent, strategic and business-oriented approach, and their commitment to fostering strong client relationships through seamless integration and harmonious coordination with client teams."	
    """
}

json_col = level_data.col_values(4)
pc_jsons = json_col[json_col.index("Proxycurl JSON") + 1:]

openai_api_key = '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'

for j in pc_jsons:
    
    client_col = level_data.col_values(2)
    client_list = client_col[client_col.index("Client") + 1:]
    client_input = client_list[pc_jsons.index(j)]
    
    print(client_col)
    print("Client Input: " + client_input)
    
    system_prompt = f"You work for a company called Level Company. You are tasked with writing a connection request on linkedIn to a potential advisor, and must first identify useful context for devising an this message. The Client you are sourcing an Advisor for is {client_input}." +  level_context + f"\n Background Information on {client_input}" + client_context

    input("Click enter to start best fields model...")
    
    chat_model = ChatOpenAI(temperature=0, model_name='gpt-4', openai_api_key=openai_api_key)
    
    
    output = chat_model(
    [        
        SystemMessage(content=system_prompt),
        HumanMessage(content=f'Write a short bio with only the most important information and why it is relevant to advising {client_input}: {j}')  
    ]
    )
    
    filtered_best_fields = str(output).replace('content=\'', '').replace('\' additional_kwargs={} example=False', '')
    
    level_data.update(f"G{pc_jsons.index(j) + 3}", filtered_best_fields)
# Out:
# ['', 'Client', 'BairesDev', 'BairesDev', 'BairesDev', 'BairesDev', 'BairesDev']
# Client Input: BairesDev
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/j0/dhfgpfdx2dqdk0_lk2mzx5r40000gn/T/ipykernel_26161/1872021892.py in <module>
#      39     system_prompt = f"You work for a company called Level Company. You are tasked with writing a connection request on linkedIn to a potential advisor, and must first identify useful context for devising an this message. The Client you are sourcing an Advisor for is {client_input}." +  level_context + f"\n Background Information on {client_input}" + client_context
#      40
# ---> 41     input("Click enter to start best fields model...")
#      42
#      43     chat_model = ChatOpenAI(temperature=0, model_name='gpt-4', openai_api_key=openai_api_key)
#
# ...

# %% [markdown]
# This is the model in an LLM chain so we can have other models connect to it

# %%
from langchain import PromptTemplate
from langchain.chains import LLMChain, SimpleSequentialChain
from langchain.chat_models import ChatOpenAI
import os

openai_api_key = os.getenv('OPENAI_API_KEY')

client_names = prompt_data.col_values(2)[18:]
client_info = prompt_data.col_values(3)[18:]
clients = {}

level_context = """
    Level Company is an innovative platform that connects businesses with trusted advisors who have strong relationships with decision-makers at large organizations. Their mission is to help businesses pitch their value proposition to the right people, shorten sales cycles, and increase the likelihood of securing high-value accounts. They address critical challenges faced by businesses when targeting such accounts, including difficulty accessing key decision-makers, time-consuming prospecting, and lack of tailored insights.

    To overcome these challenges, Level Company developed a relationship-based approach that leverages human connections and industry insights. Their platform connects businesses with advisors who have established relationships with decision-makers, streamlines prospecting through introductions and relevant insights, and enables personalized value propositions. By leveraging their platform's insights and introductions, businesses can accelerate sales cycles, scale their efforts, and gain access to an exclusive network of top-level executives.

    Overall, Level Company offers an efficient and effective solution that complements traditional sales and marketing strategies. They revolutionize the business landscape by helping businesses secure high-value accounts, drive growth, and capitalize on the value of human connections and tailored insights.
"""

chloe_template = "Hi xxx, do you have a few minutes to connect this week or next? I have a short-term advisory opportunity I’d like to run by you. I’ll share my calendar here in case its easier for coordinating: https://calendly.com/chloe-shanteau-1/15-minute-meeting Thanks! Chloe"
bri_template = "Hey name - do you have a few minutes to connect? I have a compensated advisory opportunity I’d like to run by you. Please feel free to book some time to chat here: https://calendly.com/brianna-gage/15-minute-meeting"
templates = chloe_template + "\n" + bri_template


def generate_clients():

    for i, client in enumerate(client_info):
        clients[client_names[i]] = client

def run_best_fields_model(client_input, j):

#     client_context = clients.get(client_input)
    
    best_fields_sheet = prompt_data.acell("D5").value
    best_fields_prompt = best_fields_sheet + "{j}"
    
    best_fields_prompt_template = PromptTemplate.from_template(best_fields_prompt)
    best_fields_prompt_template.format(client_input=client_input, j=j)
            
    best_fields_model = ChatOpenAI(temperature=0, model_name='gpt-4', openai_api_key=openai_api_key)
    
    best_fields_chain = LLMChain(llm=best_fields_model, prompt=best_fields_prompt_template)
    
    input("Click enter to start best fields model...")

    best_fields_output = best_fields_chain.run({
        'client_input': client_input,
        'j': j
    })
    
    level_data.update(f"I{pc_jsons.index(j) + 3}", best_fields_output)
    
    return best_fields_output

def run_init_connect_model(name, bio):
#     client_context = clients.get(client_input)
    init_connect_prompt = prompt_data.acell("D9").value + "{bio}" 
    
    init_connect_prompt_template = PromptTemplate.from_template(init_connect_prompt)
    
    init_connect_model = ChatOpenAI(temperature=0, model_name='gpt-4', openai_api_key=openai_api_key)
    
    init_connect_chain = LLMChain(llm=init_connect_model, prompt=init_connect_prompt_template)
    
#     max_attempts = 2  # Maximum number of attempts to generate a 300-character or less output
#     attempt = 1
#     init_connect_output = None
    
    input("Click enter to start Linkedin initial connection model...")
        
    init_connect_output = init_connect_chain.run({
        'client_input': client_input,
        'name': name,
        'bio': bio
    })
    
    
    level_data.update(f"J{pc_jsons.index(j) + 3}", init_connect_output)

    return init_connect_output

def run_critic_model(client_input, init_message):
    client_context = clients.get(client_input)
    
    critic_prompt = "You work for a company called Level Company. You are tasked with writing a connection request on LinkedIn to a potential advisor. Given the background of Level and it's client ({client_input}), thoroughly critique the Linkedin message below. Remember, the message can't mention any client specifics. \n {init_message}." + "\n Background on Level Company: \n" + level_context + "\n Background on {client_input}: \n" + client_context
    
    critic_prompt_template = PromptTemplate.from_template(critic_prompt)
    
    critic_model = ChatOpenAI(temperature = 0, model_name = 'gpt-4', openai_api_key=openai_api_key)
    
    critic_chain = LLMChain(llm=critic_model, prompt=critic_prompt_template)

    input("Click enter to start the critique connection model...")
    
    critic_output = critic_chain.run({
        'client_input': client_input,
        'init_message': init_message
    })
    
    level_data.update(f"K{pc_jsons.index(j) + 3}", critic_output)
    
    return critic_output

def run_revised_linkedin_model(init_message, critic, client_input):
    client_context = clients.get(client_input)

    revision_prompt = "You work for a company called Level Company. You are tasked with writing a connection request on LinkedIn to a potential advisor. Using the feedback here \n {critic}, revise the initial Linkedin connection request to incorporate the feedback and be strictly 300 characters. Do not mention any client specifics, including name. \n {init_message}" + "\n Background on Level Company: \n" + level_context + "\n Background on {client_input}: \n" + client_context
    
    revision_prompt_template = PromptTemplate.from_template(revision_prompt)
    
    revision_model = ChatOpenAI(temperature = 0, model_name = 'gpt-4', openai_api_key=openai_api_key)
    
    revision_chain = LLMChain(llm=revision_model, prompt=revision_prompt_template)
    
    input("Click enter to start revision model on the Linkedin connection request...")
    
    revision_output = revision_chain.run({
        'critic': critic,
        'init_message': init_message,
        'client_input': client_input
    })
    
    level_data.update(f"L{pc_jsons.index(j) + 3}", revision_output)

    return revision_output



generate_clients()
print(clients)

json_col = level_data.col_values(5)
pc_jsons = json_col[json_col.index("Filtered JSON") + 1:]

for j in pc_jsons:
    
    client_col = level_data.col_values(2)
    client_list = client_col[client_col.index("Client") + 1:]
    client_input = client_list[pc_jsons.index(j)]
    print(client_input)
    
    best_fields_output = run_best_fields_model(client_input, j)
    
    print(best_fields_output)
    name = j['full_name']
    
    init_connect_output = run_init_connect_model(client_input, name, best_fields_output)
    
    print(init_connect_output)
    
    critic_output = run_critic_model(client_input, init_connect_output)
    
    print(critic_output)
    
    revision_output = run_revised_linkedin_model(init_connect_output, critic_output, client_input)
    
    print(revision_output)
    
    
#     final_chain = SimpleSequentialChain(chains=[best_fields_output, init_connect_output], verbose=True)
#     final_output = final_chain.run({
#         'client_input': client_input,
#         'j': j,
#     })
    
#     print(final_output)
# Out:
# {'BairesDev': '"BairesDev is a leading Nearshore Outsourcing company that specializes in developing scalable and high-performing technology solutions for a diverse array of clients, including Fortune 500 companies. The company leverages its proficient team of software engineers and the latest technologies to innovate and digitally empower businesses across different sectors. BairesDev\'s team, distributed across 36 countries, integrates seamlessly with client\'s in-house teams using agile methodologies. Their service offering is designed to facilitate digital transformation and includes everything from requirements and systems analysis to architecture, design, development, testing, migration, and deployment. The company prides itself on its stringent recruitment process which selects only the top 1% of tech engineers from over 1.2 million applicants annually. To optimally assemble teams for different projects, BairesDev utilizes a proprietary system called Staffing Hero™, ensuring th
# ...
